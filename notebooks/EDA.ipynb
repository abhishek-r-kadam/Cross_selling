# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train = pd.read_csv(r"C:\Users\Abhishek\Downloads\archive (1)\train.csv")
df_test = pd.read_csv(r"C:\Users\Abhishek\Downloads\archive (1)\test.csv")

# %%
df_train.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
df_test.head()
# Out:
#        id Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0  381110   Male   25                1         11.0                   1
# 1  381111   Male   40                1         28.0                   0
# 2  381112   Male   47                1         28.0                   0
# 3  381113   Male   24                1         27.0                   1
# 4  381114   Male   27                1         28.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage
# 0    < 1 Year             No         35786.0                 152.0       53
# 1    1-2 Year            Yes         33762.0                   7.0      111
# 2    1-2 Year            Yes         40050.0                 124.0      199
# 3    < 1 Year            Yes         37356.0                 152.0      187
# 4    < 1 Year             No         59097.0                 152.0      297

# %%
df_train.shape
# Out:
# (381109, 12)

# %%
df_train.isna().sum()
# Out:
# id                      0
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# Response                0
# dtype: int64

# %%
df_train.duplicated().sum()
# Out:
# 0

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    381109 non-null  int64
#  1   Gender                381109 non-null  object
#  2   Age                   381109 non-null  int64
#  3   Driving_License       381109 non-null  int64
#  4   Region_Code           381109 non-null  float64
#  5   Previously_Insured    381109 non-null  int64
#  6   Vehicle_Age           381109 non-null  object
#  7   Vehicle_Damage        381109 non-null  object
#  8   Annual_Premium        381109 non-null  float64
#  9   Policy_Sales_Channel  381109 non-null  float64
#  10  Vintage               381109 non-null  int64
#  11  Response              381109 non-null  int64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 34.9+ MB

# %%
df_train.describe()
# Out:
#                   id            Age  Driving_License    Region_Code  \
# count  381109.000000  381109.000000    381109.000000  381109.000000
# mean   190555.000000      38.822584         0.997869      26.388807
# std    110016.836208      15.511611         0.046110      13.229888
# min         1.000000      20.000000         0.000000       0.000000
# 25%     95278.000000      25.000000         1.000000      15.000000
# 50%    190555.000000      36.000000         1.000000      28.000000
# 75%    285832.000000      49.000000         1.000000      35.000000
# max    381109.000000      85.000000         1.000000      52.000000
#
#        Previously_Insured  Annual_Premium  Policy_Sales_Channel  \
# count       381109.000000   381109.000000         381109.000000
# mean             0.458210    30564.389581            112.034295
# std              0.498251    17213.155057             54.203995
# min              0.000000     2630.000000              1.000000
# ...

# %%
# id column not required
df = df_train.drop(columns=["id"],axis=1)

# %%
df.head()
# Out:
#    Gender  Age  Driving_License  Region_Code  Previously_Insured Vehicle_Age  \
# 0    Male   44                1         28.0                   0   > 2 Years
# 1    Male   76                1          3.0                   0    1-2 Year
# 2    Male   47                1         28.0                   0   > 2 Years
# 3    Male   21                1         11.0                   1    < 1 Year
# 4  Female   29                1         41.0                   1    < 1 Year
#
#   Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  Response
# 0            Yes         40454.0                  26.0      217         1
# 1             No         33536.0                  26.0      183         0
# 2            Yes         38294.0                  26.0       27         1
# 3             No         28619.0                 152.0      203         0
# 4             No         27496.0                 152.0       39         0

# %%
num_col = [column for column in df.columns if df[column].dtype != "O" ]
cat_col = [column for column in df.columns if df[column].dtype == "O" ]

# %%
num_col
# Out:
# ['Age',
#  'Driving_License',
#  'Region_Code',
#  'Previously_Insured',
#  'Annual_Premium',
#  'Policy_Sales_Channel',
#  'Vintage',
#  'Response']

# %%
print(df["Region_Code"].value_counts())
print("*"*50)
print("Percentage Count >> ",(df["Region_Code"].value_counts(normalize=True)*100))
# Out:
# Region_Code
# 28.0    106415
# 8.0      33877
# 46.0     19749
# 41.0     18263
# 15.0     13308
# 30.0     12191
# 29.0     11065
# 50.0     10243
# 3.0       9251
# 11.0      9232
# 36.0      8797
# 33.0      7654
# 47.0      7436
# 35.0      6942
# 6.0       6280
# 45.0      5605
# 37.0      5501
# 18.0      5153
# 48.0      4681
# 14.0      4678
# 39.0      4644
# 10.0      4374
# 21.0      4266
# 2.0       4038
# 13.0      4036
# 7.0       3279
# 12.0      3198
# 9.0       3101
# 27.0      2823
# 32.0      2787
# 43.0      2639
# 17.0      2617
# 26.0      2587
# 25.0      2503
# 24.0      2415
# 38.0      2026
# 0.0       2021
# 16.0      2007
# 31.0      1960
# 23.0      1960
# 20.0      1935
# 49.0      1832
# 4.0       1801
# 34.0      1664
# 19.0      1535
# 22.0      1309
# 40.0      1295
# 5.0       1279
# 1.0       1008
# 44.0       808
# 42.0       591
# 52.0       267
# 51.0       183
# Name: count, dtype: int64
# **************************************************
# ...

# %%
print(df["Policy_Sales_Channel"].value_counts())
print("*"*50)
print("Percentage Count >> ",(df["Policy_Sales_Channel"].value_counts(normalize=True)*100))
# Out:
# Policy_Sales_Channel
# 152.0    134784
# 26.0      79700
# 124.0     73995
# 160.0     21779
# 156.0     10661
#           ...
# 149.0         1
# 43.0          1
# 144.0         1
# 143.0         1
# 41.0          1
# Name: count, Length: 155, dtype: int64
# **************************************************
# Percentage Count >>  Policy_Sales_Channel
# 152.0    35.366260
# 26.0     20.912652
# 124.0    19.415705
# 160.0     5.714638
# 156.0     2.797362
#            ...
# 149.0     0.000262
# 43.0      0.000262
# 144.0     0.000262
# 143.0     0.000262
# 41.0      0.000262
# Name: proportion, Length: 155, dtype: float64

# %%
print(df["Vintage"].value_counts())
print("*"*50)
print("Percentage Count >> ",(df["Vintage"].value_counts(normalize=True)*100))
# Out:
# Vintage
# 256    1418
# 73     1410
# 282    1397
# 158    1394
# 187    1392
#        ...
# 205    1235
# 89     1234
# 32     1230
# 224    1227
# 277    1226
# Name: count, Length: 290, dtype: int64
# **************************************************
# Percentage Count >>  Vintage
# 256    0.372072
# 73     0.369973
# 282    0.366562
# 158    0.365775
# 187    0.365250
#          ...
# 205    0.324054
# 89     0.323792
# 32     0.322742
# 224    0.321955
# 277    0.321693
# Name: proportion, Length: 290, dtype: float64

# %%
cat_col
# Out:
# ['Gender', 'Vehicle_Age', 'Vehicle_Damage']

# %%
# Lets check the values in categorical columns and theier percentage distribution

print(df["Gender"].value_counts())
print("*"*50)
print("Percentage Count >> ",(df["Gender"].value_counts(normalize=True)*100))
# Out:
# Gender
# Male      206089
# Female    175020
# Name: count, dtype: int64
# **************************************************
# Percentage Count >>  Gender
# Male      54.07613
# Female    45.92387
# Name: proportion, dtype: float64

# %%
print(df["Vehicle_Age"].value_counts())
print("*"*50)
print("Percentage Count >> ",(df["Vehicle_Age"].value_counts(normalize=True)*100))
# Out:
# Vehicle_Age
# 1-2 Year     200316
# < 1 Year     164786
# > 2 Years     16007
# Name: count, dtype: int64
# **************************************************
# Percentage Count >>  Vehicle_Age
# 1-2 Year     52.561341
# < 1 Year     43.238549
# > 2 Years     4.200111
# Name: proportion, dtype: float64

# %%
print(df["Vehicle_Damage"].value_counts())
print("*"*50)
print("Percentage Count >> ",(df["Vehicle_Damage"].value_counts(normalize=True)*100))
# Out:
# Vehicle_Damage
# Yes    192413
# No     188696
# Name: count, dtype: int64
# **************************************************
# Percentage Count >>  Vehicle_Damage
# Yes    50.487656
# No     49.512344
# Name: proportion, dtype: float64

# %%
# Target Column

print(df["Response"].value_counts())
print("*"*50)
print("Percentage Count >> ",(df["Response"].value_counts(normalize=True)*100))
# Out:
# Response
# 0    334399
# 1     46710
# Name: count, dtype: int64
# **************************************************
# Percentage Count >>  Response
# 0    87.743664
# 1    12.256336
# Name: proportion, dtype: float64
